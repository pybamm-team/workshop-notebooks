# %% [markdown]
# # Simulating long experiments

# %% [markdown]
# This notebook introduces functionality for simulating experiments over hundreds or even thousands of cycles.

# %%
# %pip install pybamm -q
import pybamm
import matplotlib.pyplot as plt
import numpy as np

pybamm.set_logging_level("NOTICE")
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Simulating long experiments

# %% [markdown]
# In the interest of simplicity and running time, we consider a SPM with SEI effects leading to linear degradation, with parameter values chosen so that the capacity fades by 20% in just a few cycles

# %%
parameter_values = pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Mohtat2020)
parameter_values.update({"SEI kinetic rate constant [m.s-1]": 1e-14})
spm = pybamm.lithium_ion.SPM({"SEI": "ec reaction limited"})

# %% [markdown]
# We can simulate many CCCV cycles. Here we simulate either 100 cycles or until the capacity is 80% of the initial capacity, whichever is first. The capacity is calculated by the eSOH model

# %%
experiment = pybamm.Experiment([
    ("Charge at 1C until 4.2V", 
     "Hold at 4.2V until C/50",
     "Discharge at 1C until 3V",
     "Rest for 1 hour")
] * 100,
termination="80% capacity"
)
sim = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values)
sol = sim.solve()
# Out:
# 2021-09-24 15:15:42,923 - [NOTICE] simulation.solve(784): Cycle 1/100 (100.086 ms elapsed) --------------------
# 2021-09-24 15:15:42,924 - [NOTICE] simulation.solve(818): Cycle 1/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:42,973 - [NOTICE] simulation.solve(818): Cycle 1/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,032 - [NOTICE] simulation.solve(818): Cycle 1/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,078 - [NOTICE] simulation.solve(818): Cycle 1/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,241 - [NOTICE] simulation.solve(896): Capacity is now 4.941 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,241 - [NOTICE] simulation.solve(784): Cycle 2/100 (418.223 ms elapsed) --------------------
# 2021-09-24 15:15:43,241 - [NOTICE] simulation.solve(818): Cycle 2/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,266 - [NOTICE] simulation.solve(818): Cycle 2/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,289 - [NOTICE] simulation.solve(818): Cycle 2/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,314 - [NOTICE] simulation.solve(818): Cycle 2/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,344 - [NOTICE] simulation.solve(896): Capacity is now 4.913 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,345 - [NOTICE] simulation.solve(784): Cycle 3/100 (522.062 ms elapsed) --------------------
# 2021-09-24 15:15:43,345 - [NOTICE] simulation.solve(818): Cycle 3/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,369 - [NOTICE] simulation.solve(818): Cycle 3/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,391 - [NOTICE] simulation.solve(818): Cycle 3/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,417 - [NOTICE] simulation.solve(818): Cycle 3/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,446 - [NOTICE] simulation.solve(896): Capacity is now 4.885 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,447 - [NOTICE] simulation.solve(784): Cycle 4/100 (624.112 ms elapsed) --------------------
# 2021-09-24 15:15:43,447 - [NOTICE] simulation.solve(818): Cycle 4/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,471 - [NOTICE] simulation.solve(818): Cycle 4/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,494 - [NOTICE] simulation.solve(818): Cycle 4/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,520 - [NOTICE] simulation.solve(818): Cycle 4/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,549 - [NOTICE] simulation.solve(896): Capacity is now 4.859 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,550 - [NOTICE] simulation.solve(784): Cycle 5/100 (726.890 ms elapsed) --------------------
# 2021-09-24 15:15:43,550 - [NOTICE] simulation.solve(818): Cycle 5/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,574 - [NOTICE] simulation.solve(818): Cycle 5/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,594 - [NOTICE] simulation.solve(818): Cycle 5/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,618 - [NOTICE] simulation.solve(818): Cycle 5/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,648 - [NOTICE] simulation.solve(896): Capacity is now 4.832 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,648 - [NOTICE] simulation.solve(784): Cycle 6/100 (825.676 ms elapsed) --------------------
# 2021-09-24 15:15:43,649 - [NOTICE] simulation.solve(818): Cycle 6/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,672 - [NOTICE] simulation.solve(818): Cycle 6/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,695 - [NOTICE] simulation.solve(818): Cycle 6/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,719 - [NOTICE] simulation.solve(818): Cycle 6/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,748 - [NOTICE] simulation.solve(896): Capacity is now 4.807 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,749 - [NOTICE] simulation.solve(784): Cycle 7/100 (925.872 ms elapsed) --------------------
# 2021-09-24 15:15:43,749 - [NOTICE] simulation.solve(818): Cycle 7/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,773 - [NOTICE] simulation.solve(818): Cycle 7/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,796 - [NOTICE] simulation.solve(818): Cycle 7/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,821 - [NOTICE] simulation.solve(818): Cycle 7/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,850 - [NOTICE] simulation.solve(896): Capacity is now 4.781 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,851 - [NOTICE] simulation.solve(784): Cycle 8/100 (1.028 s elapsed) --------------------
# 2021-09-24 15:15:43,851 - [NOTICE] simulation.solve(818): Cycle 8/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,874 - [NOTICE] simulation.solve(818): Cycle 8/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,897 - [NOTICE] simulation.solve(818): Cycle 8/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:43,922 - [NOTICE] simulation.solve(818): Cycle 8/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:43,951 - [NOTICE] simulation.solve(896): Capacity is now 4.756 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:43,952 - [NOTICE] simulation.solve(784): Cycle 9/100 (1.129 s elapsed) --------------------
# 2021-09-24 15:15:43,952 - [NOTICE] simulation.solve(818): Cycle 9/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:43,975 - [NOTICE] simulation.solve(818): Cycle 9/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:43,998 - [NOTICE] simulation.solve(818): Cycle 9/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,023 - [NOTICE] simulation.solve(818): Cycle 9/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,053 - [NOTICE] simulation.solve(896): Capacity is now 4.731 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,054 - [NOTICE] simulation.solve(784): Cycle 10/100 (1.231 s elapsed) --------------------
# 2021-09-24 15:15:44,054 - [NOTICE] simulation.solve(818): Cycle 10/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,077 - [NOTICE] simulation.solve(818): Cycle 10/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,100 - [NOTICE] simulation.solve(818): Cycle 10/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,125 - [NOTICE] simulation.solve(818): Cycle 10/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,155 - [NOTICE] simulation.solve(896): Capacity is now 4.707 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,156 - [NOTICE] simulation.solve(784): Cycle 11/100 (1.333 s elapsed) --------------------
# 2021-09-24 15:15:44,156 - [NOTICE] simulation.solve(818): Cycle 11/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,179 - [NOTICE] simulation.solve(818): Cycle 11/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,202 - [NOTICE] simulation.solve(818): Cycle 11/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,227 - [NOTICE] simulation.solve(818): Cycle 11/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,257 - [NOTICE] simulation.solve(896): Capacity is now 4.683 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,257 - [NOTICE] simulation.solve(784): Cycle 12/100 (1.435 s elapsed) --------------------
# 2021-09-24 15:15:44,258 - [NOTICE] simulation.solve(818): Cycle 12/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,280 - [NOTICE] simulation.solve(818): Cycle 12/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,303 - [NOTICE] simulation.solve(818): Cycle 12/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,327 - [NOTICE] simulation.solve(818): Cycle 12/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,357 - [NOTICE] simulation.solve(896): Capacity is now 4.660 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,358 - [NOTICE] simulation.solve(784): Cycle 13/100 (1.535 s elapsed) --------------------
# 2021-09-24 15:15:44,358 - [NOTICE] simulation.solve(818): Cycle 13/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,381 - [NOTICE] simulation.solve(818): Cycle 13/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,405 - [NOTICE] simulation.solve(818): Cycle 13/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,429 - [NOTICE] simulation.solve(818): Cycle 13/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,459 - [NOTICE] simulation.solve(896): Capacity is now 4.637 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,459 - [NOTICE] simulation.solve(784): Cycle 14/100 (1.637 s elapsed) --------------------
# 2021-09-24 15:15:44,460 - [NOTICE] simulation.solve(818): Cycle 14/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,482 - [NOTICE] simulation.solve(818): Cycle 14/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,506 - [NOTICE] simulation.solve(818): Cycle 14/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,530 - [NOTICE] simulation.solve(818): Cycle 14/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,559 - [NOTICE] simulation.solve(896): Capacity is now 4.614 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,560 - [NOTICE] simulation.solve(784): Cycle 15/100 (1.737 s elapsed) --------------------
# 2021-09-24 15:15:44,560 - [NOTICE] simulation.solve(818): Cycle 15/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,582 - [NOTICE] simulation.solve(818): Cycle 15/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,606 - [NOTICE] simulation.solve(818): Cycle 15/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,630 - [NOTICE] simulation.solve(818): Cycle 15/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,661 - [NOTICE] simulation.solve(896): Capacity is now 4.591 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,661 - [NOTICE] simulation.solve(784): Cycle 16/100 (1.839 s elapsed) --------------------
# 2021-09-24 15:15:44,662 - [NOTICE] simulation.solve(818): Cycle 16/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,685 - [NOTICE] simulation.solve(818): Cycle 16/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,709 - [NOTICE] simulation.solve(818): Cycle 16/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,735 - [NOTICE] simulation.solve(818): Cycle 16/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,767 - [NOTICE] simulation.solve(896): Capacity is now 4.569 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,767 - [NOTICE] simulation.solve(784): Cycle 17/100 (1.945 s elapsed) --------------------
# 2021-09-24 15:15:44,768 - [NOTICE] simulation.solve(818): Cycle 17/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,791 - [NOTICE] simulation.solve(818): Cycle 17/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,818 - [NOTICE] simulation.solve(818): Cycle 17/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,844 - [NOTICE] simulation.solve(818): Cycle 17/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,875 - [NOTICE] simulation.solve(896): Capacity is now 4.547 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,875 - [NOTICE] simulation.solve(784): Cycle 18/100 (2.053 s elapsed) --------------------
# 2021-09-24 15:15:44,876 - [NOTICE] simulation.solve(818): Cycle 18/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:44,899 - [NOTICE] simulation.solve(818): Cycle 18/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:44,924 - [NOTICE] simulation.solve(818): Cycle 18/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:44,949 - [NOTICE] simulation.solve(818): Cycle 18/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:44,979 - [NOTICE] simulation.solve(896): Capacity is now 4.526 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:44,980 - [NOTICE] simulation.solve(784): Cycle 19/100 (2.157 s elapsed) --------------------
# 2021-09-24 15:15:44,980 - [NOTICE] simulation.solve(818): Cycle 19/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,002 - [NOTICE] simulation.solve(818): Cycle 19/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,027 - [NOTICE] simulation.solve(818): Cycle 19/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,051 - [NOTICE] simulation.solve(818): Cycle 19/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,081 - [NOTICE] simulation.solve(896): Capacity is now 4.504 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,082 - [NOTICE] simulation.solve(784): Cycle 20/100 (2.259 s elapsed) --------------------
# 2021-09-24 15:15:45,083 - [NOTICE] simulation.solve(818): Cycle 20/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,110 - [NOTICE] simulation.solve(818): Cycle 20/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,136 - [NOTICE] simulation.solve(818): Cycle 20/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,159 - [NOTICE] simulation.solve(818): Cycle 20/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,189 - [NOTICE] simulation.solve(896): Capacity is now 4.483 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,190 - [NOTICE] simulation.solve(784): Cycle 21/100 (2.367 s elapsed) --------------------
# 2021-09-24 15:15:45,190 - [NOTICE] simulation.solve(818): Cycle 21/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,212 - [NOTICE] simulation.solve(818): Cycle 21/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,237 - [NOTICE] simulation.solve(818): Cycle 21/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,261 - [NOTICE] simulation.solve(818): Cycle 21/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,291 - [NOTICE] simulation.solve(896): Capacity is now 4.462 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,291 - [NOTICE] simulation.solve(784): Cycle 22/100 (2.469 s elapsed) --------------------
# 2021-09-24 15:15:45,292 - [NOTICE] simulation.solve(818): Cycle 22/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,314 - [NOTICE] simulation.solve(818): Cycle 22/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,337 - [NOTICE] simulation.solve(818): Cycle 22/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,360 - [NOTICE] simulation.solve(818): Cycle 22/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,390 - [NOTICE] simulation.solve(896): Capacity is now 4.442 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,391 - [NOTICE] simulation.solve(784): Cycle 23/100 (2.568 s elapsed) --------------------
# 2021-09-24 15:15:45,391 - [NOTICE] simulation.solve(818): Cycle 23/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,413 - [NOTICE] simulation.solve(818): Cycle 23/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,437 - [NOTICE] simulation.solve(818): Cycle 23/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,461 - [NOTICE] simulation.solve(818): Cycle 23/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,495 - [NOTICE] simulation.solve(896): Capacity is now 4.421 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,495 - [NOTICE] simulation.solve(784): Cycle 24/100 (2.672 s elapsed) --------------------
# 2021-09-24 15:15:45,496 - [NOTICE] simulation.solve(818): Cycle 24/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,519 - [NOTICE] simulation.solve(818): Cycle 24/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,546 - [NOTICE] simulation.solve(818): Cycle 24/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,572 - [NOTICE] simulation.solve(818): Cycle 24/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,604 - [NOTICE] simulation.solve(896): Capacity is now 4.401 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,604 - [NOTICE] simulation.solve(784): Cycle 25/100 (2.781 s elapsed) --------------------
# 2021-09-24 15:15:45,605 - [NOTICE] simulation.solve(818): Cycle 25/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,630 - [NOTICE] simulation.solve(818): Cycle 25/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,656 - [NOTICE] simulation.solve(818): Cycle 25/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,682 - [NOTICE] simulation.solve(818): Cycle 25/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,714 - [NOTICE] simulation.solve(896): Capacity is now 4.382 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,715 - [NOTICE] simulation.solve(784): Cycle 26/100 (2.892 s elapsed) --------------------
# 2021-09-24 15:15:45,715 - [NOTICE] simulation.solve(818): Cycle 26/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,739 - [NOTICE] simulation.solve(818): Cycle 26/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,766 - [NOTICE] simulation.solve(818): Cycle 26/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,791 - [NOTICE] simulation.solve(818): Cycle 26/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,823 - [NOTICE] simulation.solve(896): Capacity is now 4.362 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,824 - [NOTICE] simulation.solve(784): Cycle 27/100 (3.001 s elapsed) --------------------
# 2021-09-24 15:15:45,824 - [NOTICE] simulation.solve(818): Cycle 27/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,846 - [NOTICE] simulation.solve(818): Cycle 27/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,871 - [NOTICE] simulation.solve(818): Cycle 27/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,894 - [NOTICE] simulation.solve(818): Cycle 27/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:45,924 - [NOTICE] simulation.solve(896): Capacity is now 4.343 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:45,924 - [NOTICE] simulation.solve(784): Cycle 28/100 (3.101 s elapsed) --------------------
# 2021-09-24 15:15:45,924 - [NOTICE] simulation.solve(818): Cycle 28/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:45,946 - [NOTICE] simulation.solve(818): Cycle 28/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:45,969 - [NOTICE] simulation.solve(818): Cycle 28/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:45,991 - [NOTICE] simulation.solve(818): Cycle 28/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,021 - [NOTICE] simulation.solve(896): Capacity is now 4.323 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,022 - [NOTICE] simulation.solve(784): Cycle 29/100 (3.199 s elapsed) --------------------
# 2021-09-24 15:15:46,022 - [NOTICE] simulation.solve(818): Cycle 29/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,043 - [NOTICE] simulation.solve(818): Cycle 29/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,066 - [NOTICE] simulation.solve(818): Cycle 29/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,089 - [NOTICE] simulation.solve(818): Cycle 29/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,118 - [NOTICE] simulation.solve(896): Capacity is now 4.304 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,119 - [NOTICE] simulation.solve(784): Cycle 30/100 (3.296 s elapsed) --------------------
# 2021-09-24 15:15:46,119 - [NOTICE] simulation.solve(818): Cycle 30/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,141 - [NOTICE] simulation.solve(818): Cycle 30/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,164 - [NOTICE] simulation.solve(818): Cycle 30/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,188 - [NOTICE] simulation.solve(818): Cycle 30/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,218 - [NOTICE] simulation.solve(896): Capacity is now 4.286 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,218 - [NOTICE] simulation.solve(784): Cycle 31/100 (3.395 s elapsed) --------------------
# 2021-09-24 15:15:46,218 - [NOTICE] simulation.solve(818): Cycle 31/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,239 - [NOTICE] simulation.solve(818): Cycle 31/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,263 - [NOTICE] simulation.solve(818): Cycle 31/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,286 - [NOTICE] simulation.solve(818): Cycle 31/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,315 - [NOTICE] simulation.solve(896): Capacity is now 4.267 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,316 - [NOTICE] simulation.solve(784): Cycle 32/100 (3.493 s elapsed) --------------------
# 2021-09-24 15:15:46,316 - [NOTICE] simulation.solve(818): Cycle 32/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,337 - [NOTICE] simulation.solve(818): Cycle 32/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,360 - [NOTICE] simulation.solve(818): Cycle 32/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,382 - [NOTICE] simulation.solve(818): Cycle 32/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,412 - [NOTICE] simulation.solve(896): Capacity is now 4.249 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,413 - [NOTICE] simulation.solve(784): Cycle 33/100 (3.590 s elapsed) --------------------
# 2021-09-24 15:15:46,413 - [NOTICE] simulation.solve(818): Cycle 33/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,435 - [NOTICE] simulation.solve(818): Cycle 33/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,459 - [NOTICE] simulation.solve(818): Cycle 33/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,481 - [NOTICE] simulation.solve(818): Cycle 33/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,511 - [NOTICE] simulation.solve(896): Capacity is now 4.231 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,511 - [NOTICE] simulation.solve(784): Cycle 34/100 (3.689 s elapsed) --------------------
# 2021-09-24 15:15:46,512 - [NOTICE] simulation.solve(818): Cycle 34/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,533 - [NOTICE] simulation.solve(818): Cycle 34/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,556 - [NOTICE] simulation.solve(818): Cycle 34/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,578 - [NOTICE] simulation.solve(818): Cycle 34/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,608 - [NOTICE] simulation.solve(896): Capacity is now 4.213 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,609 - [NOTICE] simulation.solve(784): Cycle 35/100 (3.786 s elapsed) --------------------
# 2021-09-24 15:15:46,609 - [NOTICE] simulation.solve(818): Cycle 35/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,630 - [NOTICE] simulation.solve(818): Cycle 35/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,653 - [NOTICE] simulation.solve(818): Cycle 35/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,676 - [NOTICE] simulation.solve(818): Cycle 35/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,706 - [NOTICE] simulation.solve(896): Capacity is now 4.195 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,706 - [NOTICE] simulation.solve(784): Cycle 36/100 (3.883 s elapsed) --------------------
# 2021-09-24 15:15:46,706 - [NOTICE] simulation.solve(818): Cycle 36/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,728 - [NOTICE] simulation.solve(818): Cycle 36/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,751 - [NOTICE] simulation.solve(818): Cycle 36/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,774 - [NOTICE] simulation.solve(818): Cycle 36/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,803 - [NOTICE] simulation.solve(896): Capacity is now 4.177 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,804 - [NOTICE] simulation.solve(784): Cycle 37/100 (3.981 s elapsed) --------------------
# 2021-09-24 15:15:46,804 - [NOTICE] simulation.solve(818): Cycle 37/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,824 - [NOTICE] simulation.solve(818): Cycle 37/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,847 - [NOTICE] simulation.solve(818): Cycle 37/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,869 - [NOTICE] simulation.solve(818): Cycle 37/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,898 - [NOTICE] simulation.solve(896): Capacity is now 4.160 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,899 - [NOTICE] simulation.solve(784): Cycle 38/100 (4.076 s elapsed) --------------------
# 2021-09-24 15:15:46,899 - [NOTICE] simulation.solve(818): Cycle 38/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:46,919 - [NOTICE] simulation.solve(818): Cycle 38/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:46,943 - [NOTICE] simulation.solve(818): Cycle 38/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:46,964 - [NOTICE] simulation.solve(818): Cycle 38/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:46,994 - [NOTICE] simulation.solve(896): Capacity is now 4.142 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:46,995 - [NOTICE] simulation.solve(784): Cycle 39/100 (4.172 s elapsed) --------------------
# 2021-09-24 15:15:46,995 - [NOTICE] simulation.solve(818): Cycle 39/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,017 - [NOTICE] simulation.solve(818): Cycle 39/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,040 - [NOTICE] simulation.solve(818): Cycle 39/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,153 - [NOTICE] simulation.solve(818): Cycle 39/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,183 - [NOTICE] simulation.solve(896): Capacity is now 4.125 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,183 - [NOTICE] simulation.solve(784): Cycle 40/100 (4.360 s elapsed) --------------------
# 2021-09-24 15:15:47,183 - [NOTICE] simulation.solve(818): Cycle 40/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,204 - [NOTICE] simulation.solve(818): Cycle 40/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,228 - [NOTICE] simulation.solve(818): Cycle 40/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,250 - [NOTICE] simulation.solve(818): Cycle 40/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,279 - [NOTICE] simulation.solve(896): Capacity is now 4.108 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,280 - [NOTICE] simulation.solve(784): Cycle 41/100 (4.457 s elapsed) --------------------
# 2021-09-24 15:15:47,280 - [NOTICE] simulation.solve(818): Cycle 41/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,301 - [NOTICE] simulation.solve(818): Cycle 41/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,324 - [NOTICE] simulation.solve(818): Cycle 41/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,347 - [NOTICE] simulation.solve(818): Cycle 41/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,379 - [NOTICE] simulation.solve(896): Capacity is now 4.091 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,379 - [NOTICE] simulation.solve(784): Cycle 42/100 (4.557 s elapsed) --------------------
# 2021-09-24 15:15:47,380 - [NOTICE] simulation.solve(818): Cycle 42/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,401 - [NOTICE] simulation.solve(818): Cycle 42/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,427 - [NOTICE] simulation.solve(818): Cycle 42/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,451 - [NOTICE] simulation.solve(818): Cycle 42/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,482 - [NOTICE] simulation.solve(896): Capacity is now 4.075 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,482 - [NOTICE] simulation.solve(784): Cycle 43/100 (4.660 s elapsed) --------------------
# 2021-09-24 15:15:47,483 - [NOTICE] simulation.solve(818): Cycle 43/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,504 - [NOTICE] simulation.solve(818): Cycle 43/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,528 - [NOTICE] simulation.solve(818): Cycle 43/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,550 - [NOTICE] simulation.solve(818): Cycle 43/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,586 - [NOTICE] simulation.solve(896): Capacity is now 4.058 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,587 - [NOTICE] simulation.solve(784): Cycle 44/100 (4.764 s elapsed) --------------------
# 2021-09-24 15:15:47,587 - [NOTICE] simulation.solve(818): Cycle 44/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,608 - [NOTICE] simulation.solve(818): Cycle 44/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,632 - [NOTICE] simulation.solve(818): Cycle 44/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,655 - [NOTICE] simulation.solve(818): Cycle 44/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,685 - [NOTICE] simulation.solve(896): Capacity is now 4.042 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,685 - [NOTICE] simulation.solve(784): Cycle 45/100 (4.862 s elapsed) --------------------
# 2021-09-24 15:15:47,686 - [NOTICE] simulation.solve(818): Cycle 45/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,706 - [NOTICE] simulation.solve(818): Cycle 45/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,731 - [NOTICE] simulation.solve(818): Cycle 45/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,754 - [NOTICE] simulation.solve(818): Cycle 45/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,783 - [NOTICE] simulation.solve(896): Capacity is now 4.026 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,784 - [NOTICE] simulation.solve(784): Cycle 46/100 (4.961 s elapsed) --------------------
# 2021-09-24 15:15:47,784 - [NOTICE] simulation.solve(818): Cycle 46/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,804 - [NOTICE] simulation.solve(818): Cycle 46/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,829 - [NOTICE] simulation.solve(818): Cycle 46/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,851 - [NOTICE] simulation.solve(818): Cycle 46/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,881 - [NOTICE] simulation.solve(896): Capacity is now 4.009 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,881 - [NOTICE] simulation.solve(784): Cycle 47/100 (5.058 s elapsed) --------------------
# 2021-09-24 15:15:47,881 - [NOTICE] simulation.solve(818): Cycle 47/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,902 - [NOTICE] simulation.solve(818): Cycle 47/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:47,926 - [NOTICE] simulation.solve(818): Cycle 47/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:47,947 - [NOTICE] simulation.solve(818): Cycle 47/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:47,977 - [NOTICE] simulation.solve(896): Capacity is now 3.994 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:47,977 - [NOTICE] simulation.solve(784): Cycle 48/100 (5.154 s elapsed) --------------------
# 2021-09-24 15:15:47,977 - [NOTICE] simulation.solve(818): Cycle 48/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:47,999 - [NOTICE] simulation.solve(818): Cycle 48/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:48,026 - [NOTICE] simulation.solve(818): Cycle 48/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:48,048 - [NOTICE] simulation.solve(818): Cycle 48/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:48,079 - [NOTICE] simulation.solve(896): Capacity is now 3.978 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:48,080 - [NOTICE] simulation.solve(784): Cycle 49/100 (5.257 s elapsed) --------------------
# 2021-09-24 15:15:48,080 - [NOTICE] simulation.solve(818): Cycle 49/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:48,103 - [NOTICE] simulation.solve(818): Cycle 49/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:48,130 - [NOTICE] simulation.solve(818): Cycle 49/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:48,153 - [NOTICE] simulation.solve(818): Cycle 49/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:48,183 - [NOTICE] simulation.solve(896): Capacity is now 3.962 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:48,184 - [NOTICE] simulation.solve(784): Cycle 50/100 (5.361 s elapsed) --------------------
# 2021-09-24 15:15:48,184 - [NOTICE] simulation.solve(818): Cycle 50/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:48,205 - [NOTICE] simulation.solve(818): Cycle 50/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:48,231 - [NOTICE] simulation.solve(818): Cycle 50/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:48,253 - [NOTICE] simulation.solve(818): Cycle 50/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:48,282 - [NOTICE] simulation.solve(902): Stopping experiment since capacity (3.947 Ah) is below stopping capacity (3.952 Ah).
# 2021-09-24 15:15:48,284 - [NOTICE] simulation.solve(913): Finish experiment simulation, took 5.461 s

# %% [markdown]
# We can plot standard variables like the current and voltage, but it isn't very instructive on these timescales

# %%
sol.plot(["Current [A]", "Terminal voltage [V]"])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=146.9491051741843, step=1.469491051741843), …

# %% [markdown]
# Some other variables are more interesting

# %%
sim.plot([
    "Negative electrode SOC", 
    "Positive electrode SOC",
    "Total lithium in particles [mol]",
    "Loss of lithium to negative electrode SEI [mol]",
    "X-averaged negative electrode SEI thickness [m]",
])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=146.9491051741843, step=1.469491051741843), …

# %%
fig, ax = plt.subplots()
for i,cycle in enumerate(sim.solution.cycles):
    if i%10==0:
        t = cycle["Time [s]"].data
        LLI = cycle["Loss of lithium inventory [%]"].data
        ax.plot(t-t[0], LLI-LLI[0])

# %% [markdown]
# ## Summary variables

# %% [markdown]
# We can also plot "summary variables", which show how the battery degrades over time by various metrics. Some of the variables also have "Change in ...", which is how much that variable changes over each cycle.

# %%
sorted(sol.summary_variables.keys())
# Out:
# ['C',
#  'C_n',
#  'C_n * (x_100 - x_0)',
#  'C_p',
#  'C_p * (y_100 - y_0)',
#  'Capacity [A.h]',
#  'Change in local ECM resistance [Ohm]',
#  'Change in loss of active material in negative electrode [%]',
#  'Change in loss of active material in positive electrode [%]',
#  'Change in loss of capacity to negative electrode SEI [A.h]',
#  'Change in loss of capacity to negative electrode lithium plating [A.h]',
#  'Change in loss of capacity to positive electrode SEI [A.h]',
#  'Change in loss of capacity to positive electrode lithium plating [A.h]',
#  'Change in loss of lithium inventory [%]',
#  'Change in loss of lithium inventory, including electrolyte [%]',
#  'Change in loss of lithium to negative electrode SEI [mol]',
#  'Change in loss of lithium to negative electrode lithium plating [mol]',
#  'Change in loss of lithium to positive electrode SEI [mol]',
#  'Change in loss of lithium to positive electrode lithium plating [mol]',
#  'Change in negative electrode capacity [A.h]',
#  'Change in positive electrode capacity [A.h]',
#  'Change in total capacity lost to side reactions [A.h]',
#  'Change in total lithium [mol]',
#  'Change in total lithium in electrolyte [mol]',
#  'Change in total lithium in negative electrode [mol]',
#  'Change in total lithium in particles [mol]',
#  'Change in total lithium in positive electrode [mol]',
#  'Change in total lithium lost [mol]',
#  'Change in total lithium lost from electrolyte [mol]',
#  'Change in total lithium lost from particles [mol]',
#  'Change in total lithium lost to side reactions [mol]',
#  'Cycle number',
#  'Local ECM resistance [Ohm]',
#  'Loss of active material in negative electrode [%]',
#  'Loss of active material in positive electrode [%]',
#  'Loss of capacity to negative electrode SEI [A.h]',
#  'Loss of capacity to negative electrode lithium plating [A.h]',
#  'Loss of capacity to positive electrode SEI [A.h]',
#  'Loss of capacity to positive electrode lithium plating [A.h]',
#  'Loss of lithium inventory [%]',
#  'Loss of lithium inventory, including electrolyte [%]',
#  'Loss of lithium to negative electrode SEI [mol]',
#  'Loss of lithium to negative electrode lithium plating [mol]',
#  'Loss of lithium to positive electrode SEI [mol]',
#  'Loss of lithium to positive electrode lithium plating [mol]',
#  'Maximum measured discharge capacity [A.h]',
#  'Measured capacity [A.h]',
#  'Minimum measured discharge capacity [A.h]',
#  'Negative electrode capacity [A.h]',
#  'Positive electrode capacity [A.h]',
#  'Total capacity lost to side reactions [A.h]',
#  'Total lithium [mol]',
#  'Total lithium in electrolyte [mol]',
#  'Total lithium in negative electrode [mol]',
#  'Total lithium in particles [mol]',
#  'Total lithium in positive electrode [mol]',
#  'Total lithium lost [mol]',
#  'Total lithium lost from electrolyte [mol]',
#  'Total lithium lost from particles [mol]',
#  'Total lithium lost to side reactions [mol]',
#  'Un(x_0)',
#  'Un(x_100)',
#  'Up(y_0)',
#  'Up(y_0) - Un(x_0)',
#  'Up(y_100)',
#  'Up(y_100) - Un(x_100)',
#  'n_Li',
#  'n_Li_0',
#  'n_Li_100',
#  'x_0',
#  'x_100',
#  'y_0',
#  'y_100']

# %% [markdown]
# Here the only degradation mechanism is one that causes loss of lithium, so we don't see loss of active material

# %%
vars_to_plot = [
    "Capacity [A.h]",
    "Loss of lithium inventory [%]",
    "x_100",
    "x_0",
    "y_100",
    "y_0"
]
l = len(vars_to_plot)
n = int(l//np.sqrt(l))
m = int(np.ceil(l/n))

fig, axes = plt.subplots(n,m,figsize=(10,6))
for var, ax in zip(vars_to_plot,axes.flat):
    ax.plot(sol.summary_variables["Cycle number"], sol.summary_variables[var])
    ax.set_xlabel("Cycle number")
    ax.set_ylabel(var)
    ax.set_xlim([1,sol.summary_variables["Cycle number"][-1]])
fig.tight_layout()

# %% [markdown]
# To suggest additional summary variables, open an issue!

# %% [markdown]
# ## Choosing which cycles to save

# %% [markdown]
# If the simulation contains thousands of cycles, saving each cycle in RAM might not be possible. To get around this, we can use `save_at_cycles`. If this is an integer `n`, every nth cycle is saved. If this is a list, all the cycles in the list are saved.
# The first cycle is always saved.

# %%
# With integer
sim = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values)
sol_int = sim.solve(save_at_cycles=5)
# With list
sim = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values)
sol_list = sim.solve(save_at_cycles=[20,30,45])
# Out:
# 2021-09-24 15:15:52,403 - [NOTICE] simulation.solve(784): Cycle 1/100 (25.598 ms elapsed) --------------------
# 2021-09-24 15:15:52,404 - [NOTICE] simulation.solve(818): Cycle 1/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:52,448 - [NOTICE] simulation.solve(818): Cycle 1/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:52,504 - [NOTICE] simulation.solve(818): Cycle 1/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:52,552 - [NOTICE] simulation.solve(818): Cycle 1/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:52,729 - [NOTICE] simulation.solve(896): Capacity is now 4.941 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:52,729 - [NOTICE] simulation.solve(784): Cycle 2/100 (351.862 ms elapsed) --------------------
# 2021-09-24 15:15:52,730 - [NOTICE] simulation.solve(818): Cycle 2/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:52,753 - [NOTICE] simulation.solve(818): Cycle 2/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:52,775 - [NOTICE] simulation.solve(818): Cycle 2/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:52,799 - [NOTICE] simulation.solve(818): Cycle 2/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:52,827 - [NOTICE] simulation.solve(896): Capacity is now 4.913 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:52,828 - [NOTICE] simulation.solve(784): Cycle 3/100 (450.108 ms elapsed) --------------------
# 2021-09-24 15:15:52,828 - [NOTICE] simulation.solve(818): Cycle 3/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:52,851 - [NOTICE] simulation.solve(818): Cycle 3/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:52,872 - [NOTICE] simulation.solve(818): Cycle 3/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:52,897 - [NOTICE] simulation.solve(818): Cycle 3/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:52,927 - [NOTICE] simulation.solve(896): Capacity is now 4.885 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:52,927 - [NOTICE] simulation.solve(784): Cycle 4/100 (549.640 ms elapsed) --------------------
# 2021-09-24 15:15:52,928 - [NOTICE] simulation.solve(818): Cycle 4/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:52,952 - [NOTICE] simulation.solve(818): Cycle 4/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:52,973 - [NOTICE] simulation.solve(818): Cycle 4/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,000 - [NOTICE] simulation.solve(818): Cycle 4/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,029 - [NOTICE] simulation.solve(896): Capacity is now 4.859 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,030 - [NOTICE] simulation.solve(784): Cycle 5/100 (652.291 ms elapsed) --------------------
# 2021-09-24 15:15:53,030 - [NOTICE] simulation.solve(818): Cycle 5/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,056 - [NOTICE] simulation.solve(818): Cycle 5/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,075 - [NOTICE] simulation.solve(818): Cycle 5/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,099 - [NOTICE] simulation.solve(818): Cycle 5/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,128 - [NOTICE] simulation.solve(896): Capacity is now 4.832 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,128 - [NOTICE] simulation.solve(784): Cycle 6/100 (750.662 ms elapsed) --------------------
# 2021-09-24 15:15:53,129 - [NOTICE] simulation.solve(818): Cycle 6/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,151 - [NOTICE] simulation.solve(818): Cycle 6/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,173 - [NOTICE] simulation.solve(818): Cycle 6/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,198 - [NOTICE] simulation.solve(818): Cycle 6/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,227 - [NOTICE] simulation.solve(896): Capacity is now 4.807 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,228 - [NOTICE] simulation.solve(784): Cycle 7/100 (850.025 ms elapsed) --------------------
# 2021-09-24 15:15:53,228 - [NOTICE] simulation.solve(818): Cycle 7/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,250 - [NOTICE] simulation.solve(818): Cycle 7/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,274 - [NOTICE] simulation.solve(818): Cycle 7/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,300 - [NOTICE] simulation.solve(818): Cycle 7/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,330 - [NOTICE] simulation.solve(896): Capacity is now 4.781 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,331 - [NOTICE] simulation.solve(784): Cycle 8/100 (953.129 ms elapsed) --------------------
# 2021-09-24 15:15:53,331 - [NOTICE] simulation.solve(818): Cycle 8/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,353 - [NOTICE] simulation.solve(818): Cycle 8/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,378 - [NOTICE] simulation.solve(818): Cycle 8/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,403 - [NOTICE] simulation.solve(818): Cycle 8/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,431 - [NOTICE] simulation.solve(896): Capacity is now 4.756 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,432 - [NOTICE] simulation.solve(784): Cycle 9/100 (1.054 s elapsed) --------------------
# 2021-09-24 15:15:53,432 - [NOTICE] simulation.solve(818): Cycle 9/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,454 - [NOTICE] simulation.solve(818): Cycle 9/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,478 - [NOTICE] simulation.solve(818): Cycle 9/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,503 - [NOTICE] simulation.solve(818): Cycle 9/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,533 - [NOTICE] simulation.solve(896): Capacity is now 4.731 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,534 - [NOTICE] simulation.solve(784): Cycle 10/100 (1.156 s elapsed) --------------------
# 2021-09-24 15:15:53,534 - [NOTICE] simulation.solve(818): Cycle 10/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,556 - [NOTICE] simulation.solve(818): Cycle 10/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,579 - [NOTICE] simulation.solve(818): Cycle 10/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,603 - [NOTICE] simulation.solve(818): Cycle 10/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,631 - [NOTICE] simulation.solve(896): Capacity is now 4.707 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,632 - [NOTICE] simulation.solve(784): Cycle 11/100 (1.254 s elapsed) --------------------
# 2021-09-24 15:15:53,632 - [NOTICE] simulation.solve(818): Cycle 11/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,656 - [NOTICE] simulation.solve(818): Cycle 11/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,678 - [NOTICE] simulation.solve(818): Cycle 11/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,703 - [NOTICE] simulation.solve(818): Cycle 11/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,732 - [NOTICE] simulation.solve(896): Capacity is now 4.683 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,732 - [NOTICE] simulation.solve(784): Cycle 12/100 (1.355 s elapsed) --------------------
# 2021-09-24 15:15:53,733 - [NOTICE] simulation.solve(818): Cycle 12/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,754 - [NOTICE] simulation.solve(818): Cycle 12/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,777 - [NOTICE] simulation.solve(818): Cycle 12/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,800 - [NOTICE] simulation.solve(818): Cycle 12/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,828 - [NOTICE] simulation.solve(896): Capacity is now 4.660 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,828 - [NOTICE] simulation.solve(784): Cycle 13/100 (1.451 s elapsed) --------------------
# 2021-09-24 15:15:53,829 - [NOTICE] simulation.solve(818): Cycle 13/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,850 - [NOTICE] simulation.solve(818): Cycle 13/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,873 - [NOTICE] simulation.solve(818): Cycle 13/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,896 - [NOTICE] simulation.solve(818): Cycle 13/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:53,924 - [NOTICE] simulation.solve(896): Capacity is now 4.637 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:53,925 - [NOTICE] simulation.solve(784): Cycle 14/100 (1.547 s elapsed) --------------------
# 2021-09-24 15:15:53,925 - [NOTICE] simulation.solve(818): Cycle 14/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:53,948 - [NOTICE] simulation.solve(818): Cycle 14/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:53,971 - [NOTICE] simulation.solve(818): Cycle 14/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:53,995 - [NOTICE] simulation.solve(818): Cycle 14/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,025 - [NOTICE] simulation.solve(896): Capacity is now 4.614 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,025 - [NOTICE] simulation.solve(784): Cycle 15/100 (1.648 s elapsed) --------------------
# 2021-09-24 15:15:54,026 - [NOTICE] simulation.solve(818): Cycle 15/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,048 - [NOTICE] simulation.solve(818): Cycle 15/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,071 - [NOTICE] simulation.solve(818): Cycle 15/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,094 - [NOTICE] simulation.solve(818): Cycle 15/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,123 - [NOTICE] simulation.solve(896): Capacity is now 4.591 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,123 - [NOTICE] simulation.solve(784): Cycle 16/100 (1.745 s elapsed) --------------------
# 2021-09-24 15:15:54,123 - [NOTICE] simulation.solve(818): Cycle 16/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,146 - [NOTICE] simulation.solve(818): Cycle 16/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,169 - [NOTICE] simulation.solve(818): Cycle 16/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,192 - [NOTICE] simulation.solve(818): Cycle 16/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,220 - [NOTICE] simulation.solve(896): Capacity is now 4.569 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,220 - [NOTICE] simulation.solve(784): Cycle 17/100 (1.842 s elapsed) --------------------
# 2021-09-24 15:15:54,220 - [NOTICE] simulation.solve(818): Cycle 17/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,241 - [NOTICE] simulation.solve(818): Cycle 17/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,264 - [NOTICE] simulation.solve(818): Cycle 17/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,287 - [NOTICE] simulation.solve(818): Cycle 17/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,315 - [NOTICE] simulation.solve(896): Capacity is now 4.547 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,316 - [NOTICE] simulation.solve(784): Cycle 18/100 (1.938 s elapsed) --------------------
# 2021-09-24 15:15:54,316 - [NOTICE] simulation.solve(818): Cycle 18/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,337 - [NOTICE] simulation.solve(818): Cycle 18/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,360 - [NOTICE] simulation.solve(818): Cycle 18/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,384 - [NOTICE] simulation.solve(818): Cycle 18/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,414 - [NOTICE] simulation.solve(896): Capacity is now 4.526 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,415 - [NOTICE] simulation.solve(784): Cycle 19/100 (2.037 s elapsed) --------------------
# 2021-09-24 15:15:54,415 - [NOTICE] simulation.solve(818): Cycle 19/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,436 - [NOTICE] simulation.solve(818): Cycle 19/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,459 - [NOTICE] simulation.solve(818): Cycle 19/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,481 - [NOTICE] simulation.solve(818): Cycle 19/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,509 - [NOTICE] simulation.solve(896): Capacity is now 4.504 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,510 - [NOTICE] simulation.solve(784): Cycle 20/100 (2.132 s elapsed) --------------------
# 2021-09-24 15:15:54,510 - [NOTICE] simulation.solve(818): Cycle 20/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,531 - [NOTICE] simulation.solve(818): Cycle 20/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,554 - [NOTICE] simulation.solve(818): Cycle 20/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,576 - [NOTICE] simulation.solve(818): Cycle 20/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,604 - [NOTICE] simulation.solve(896): Capacity is now 4.483 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,605 - [NOTICE] simulation.solve(784): Cycle 21/100 (2.227 s elapsed) --------------------
# 2021-09-24 15:15:54,605 - [NOTICE] simulation.solve(818): Cycle 21/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,626 - [NOTICE] simulation.solve(818): Cycle 21/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,651 - [NOTICE] simulation.solve(818): Cycle 21/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,675 - [NOTICE] simulation.solve(818): Cycle 21/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,706 - [NOTICE] simulation.solve(896): Capacity is now 4.462 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,706 - [NOTICE] simulation.solve(784): Cycle 22/100 (2.329 s elapsed) --------------------
# 2021-09-24 15:15:54,707 - [NOTICE] simulation.solve(818): Cycle 22/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,731 - [NOTICE] simulation.solve(818): Cycle 22/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,755 - [NOTICE] simulation.solve(818): Cycle 22/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,778 - [NOTICE] simulation.solve(818): Cycle 22/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,807 - [NOTICE] simulation.solve(896): Capacity is now 4.442 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,808 - [NOTICE] simulation.solve(784): Cycle 23/100 (2.430 s elapsed) --------------------
# 2021-09-24 15:15:54,808 - [NOTICE] simulation.solve(818): Cycle 23/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,829 - [NOTICE] simulation.solve(818): Cycle 23/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,852 - [NOTICE] simulation.solve(818): Cycle 23/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,875 - [NOTICE] simulation.solve(818): Cycle 23/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,903 - [NOTICE] simulation.solve(896): Capacity is now 4.421 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,903 - [NOTICE] simulation.solve(784): Cycle 24/100 (2.526 s elapsed) --------------------
# 2021-09-24 15:15:54,904 - [NOTICE] simulation.solve(818): Cycle 24/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:54,924 - [NOTICE] simulation.solve(818): Cycle 24/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:54,947 - [NOTICE] simulation.solve(818): Cycle 24/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:54,969 - [NOTICE] simulation.solve(818): Cycle 24/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:54,998 - [NOTICE] simulation.solve(896): Capacity is now 4.401 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:54,998 - [NOTICE] simulation.solve(784): Cycle 25/100 (2.621 s elapsed) --------------------
# 2021-09-24 15:15:54,999 - [NOTICE] simulation.solve(818): Cycle 25/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,020 - [NOTICE] simulation.solve(818): Cycle 25/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,043 - [NOTICE] simulation.solve(818): Cycle 25/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,065 - [NOTICE] simulation.solve(818): Cycle 25/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,095 - [NOTICE] simulation.solve(896): Capacity is now 4.382 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,095 - [NOTICE] simulation.solve(784): Cycle 26/100 (2.717 s elapsed) --------------------
# 2021-09-24 15:15:55,095 - [NOTICE] simulation.solve(818): Cycle 26/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,116 - [NOTICE] simulation.solve(818): Cycle 26/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,138 - [NOTICE] simulation.solve(818): Cycle 26/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,161 - [NOTICE] simulation.solve(818): Cycle 26/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,189 - [NOTICE] simulation.solve(896): Capacity is now 4.362 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,190 - [NOTICE] simulation.solve(784): Cycle 27/100 (2.812 s elapsed) --------------------
# 2021-09-24 15:15:55,190 - [NOTICE] simulation.solve(818): Cycle 27/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,210 - [NOTICE] simulation.solve(818): Cycle 27/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,232 - [NOTICE] simulation.solve(818): Cycle 27/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,254 - [NOTICE] simulation.solve(818): Cycle 27/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,282 - [NOTICE] simulation.solve(896): Capacity is now 4.343 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,283 - [NOTICE] simulation.solve(784): Cycle 28/100 (2.905 s elapsed) --------------------
# 2021-09-24 15:15:55,283 - [NOTICE] simulation.solve(818): Cycle 28/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,303 - [NOTICE] simulation.solve(818): Cycle 28/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,325 - [NOTICE] simulation.solve(818): Cycle 28/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,347 - [NOTICE] simulation.solve(818): Cycle 28/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,375 - [NOTICE] simulation.solve(896): Capacity is now 4.323 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,375 - [NOTICE] simulation.solve(784): Cycle 29/100 (2.998 s elapsed) --------------------
# 2021-09-24 15:15:55,376 - [NOTICE] simulation.solve(818): Cycle 29/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,396 - [NOTICE] simulation.solve(818): Cycle 29/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,418 - [NOTICE] simulation.solve(818): Cycle 29/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,442 - [NOTICE] simulation.solve(818): Cycle 29/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,469 - [NOTICE] simulation.solve(896): Capacity is now 4.304 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,470 - [NOTICE] simulation.solve(784): Cycle 30/100 (3.092 s elapsed) --------------------
# 2021-09-24 15:15:55,470 - [NOTICE] simulation.solve(818): Cycle 30/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,490 - [NOTICE] simulation.solve(818): Cycle 30/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,512 - [NOTICE] simulation.solve(818): Cycle 30/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,534 - [NOTICE] simulation.solve(818): Cycle 30/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,562 - [NOTICE] simulation.solve(896): Capacity is now 4.286 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,562 - [NOTICE] simulation.solve(784): Cycle 31/100 (3.185 s elapsed) --------------------
# 2021-09-24 15:15:55,562 - [NOTICE] simulation.solve(818): Cycle 31/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,582 - [NOTICE] simulation.solve(818): Cycle 31/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,605 - [NOTICE] simulation.solve(818): Cycle 31/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,627 - [NOTICE] simulation.solve(818): Cycle 31/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,655 - [NOTICE] simulation.solve(896): Capacity is now 4.267 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,655 - [NOTICE] simulation.solve(784): Cycle 32/100 (3.278 s elapsed) --------------------
# 2021-09-24 15:15:55,655 - [NOTICE] simulation.solve(818): Cycle 32/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,675 - [NOTICE] simulation.solve(818): Cycle 32/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,698 - [NOTICE] simulation.solve(818): Cycle 32/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,719 - [NOTICE] simulation.solve(818): Cycle 32/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,747 - [NOTICE] simulation.solve(896): Capacity is now 4.249 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,748 - [NOTICE] simulation.solve(784): Cycle 33/100 (3.370 s elapsed) --------------------
# 2021-09-24 15:15:55,748 - [NOTICE] simulation.solve(818): Cycle 33/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,768 - [NOTICE] simulation.solve(818): Cycle 33/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,792 - [NOTICE] simulation.solve(818): Cycle 33/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,814 - [NOTICE] simulation.solve(818): Cycle 33/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,842 - [NOTICE] simulation.solve(896): Capacity is now 4.231 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,842 - [NOTICE] simulation.solve(784): Cycle 34/100 (3.464 s elapsed) --------------------
# 2021-09-24 15:15:55,842 - [NOTICE] simulation.solve(818): Cycle 34/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,862 - [NOTICE] simulation.solve(818): Cycle 34/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,885 - [NOTICE] simulation.solve(818): Cycle 34/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,906 - [NOTICE] simulation.solve(818): Cycle 34/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:55,934 - [NOTICE] simulation.solve(896): Capacity is now 4.213 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:55,935 - [NOTICE] simulation.solve(784): Cycle 35/100 (3.557 s elapsed) --------------------
# 2021-09-24 15:15:55,935 - [NOTICE] simulation.solve(818): Cycle 35/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:55,955 - [NOTICE] simulation.solve(818): Cycle 35/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:55,977 - [NOTICE] simulation.solve(818): Cycle 35/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:55,999 - [NOTICE] simulation.solve(818): Cycle 35/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,027 - [NOTICE] simulation.solve(896): Capacity is now 4.195 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,028 - [NOTICE] simulation.solve(784): Cycle 36/100 (3.650 s elapsed) --------------------
# 2021-09-24 15:15:56,028 - [NOTICE] simulation.solve(818): Cycle 36/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,048 - [NOTICE] simulation.solve(818): Cycle 36/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,070 - [NOTICE] simulation.solve(818): Cycle 36/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,092 - [NOTICE] simulation.solve(818): Cycle 36/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,121 - [NOTICE] simulation.solve(896): Capacity is now 4.177 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,122 - [NOTICE] simulation.solve(784): Cycle 37/100 (3.744 s elapsed) --------------------
# 2021-09-24 15:15:56,122 - [NOTICE] simulation.solve(818): Cycle 37/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,141 - [NOTICE] simulation.solve(818): Cycle 37/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,164 - [NOTICE] simulation.solve(818): Cycle 37/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,185 - [NOTICE] simulation.solve(818): Cycle 37/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,213 - [NOTICE] simulation.solve(896): Capacity is now 4.160 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,213 - [NOTICE] simulation.solve(784): Cycle 38/100 (3.835 s elapsed) --------------------
# 2021-09-24 15:15:56,213 - [NOTICE] simulation.solve(818): Cycle 38/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,233 - [NOTICE] simulation.solve(818): Cycle 38/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,255 - [NOTICE] simulation.solve(818): Cycle 38/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,276 - [NOTICE] simulation.solve(818): Cycle 38/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,304 - [NOTICE] simulation.solve(896): Capacity is now 4.142 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,305 - [NOTICE] simulation.solve(784): Cycle 39/100 (3.927 s elapsed) --------------------
# 2021-09-24 15:15:56,305 - [NOTICE] simulation.solve(818): Cycle 39/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,325 - [NOTICE] simulation.solve(818): Cycle 39/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,347 - [NOTICE] simulation.solve(818): Cycle 39/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,369 - [NOTICE] simulation.solve(818): Cycle 39/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,396 - [NOTICE] simulation.solve(896): Capacity is now 4.125 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,397 - [NOTICE] simulation.solve(784): Cycle 40/100 (4.019 s elapsed) --------------------
# 2021-09-24 15:15:56,397 - [NOTICE] simulation.solve(818): Cycle 40/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,416 - [NOTICE] simulation.solve(818): Cycle 40/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,439 - [NOTICE] simulation.solve(818): Cycle 40/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,461 - [NOTICE] simulation.solve(818): Cycle 40/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,490 - [NOTICE] simulation.solve(896): Capacity is now 4.108 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,491 - [NOTICE] simulation.solve(784): Cycle 41/100 (4.113 s elapsed) --------------------
# 2021-09-24 15:15:56,491 - [NOTICE] simulation.solve(818): Cycle 41/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,511 - [NOTICE] simulation.solve(818): Cycle 41/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,533 - [NOTICE] simulation.solve(818): Cycle 41/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,554 - [NOTICE] simulation.solve(818): Cycle 41/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,582 - [NOTICE] simulation.solve(896): Capacity is now 4.091 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,583 - [NOTICE] simulation.solve(784): Cycle 42/100 (4.205 s elapsed) --------------------
# 2021-09-24 15:15:56,583 - [NOTICE] simulation.solve(818): Cycle 42/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,602 - [NOTICE] simulation.solve(818): Cycle 42/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,625 - [NOTICE] simulation.solve(818): Cycle 42/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,646 - [NOTICE] simulation.solve(818): Cycle 42/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,674 - [NOTICE] simulation.solve(896): Capacity is now 4.075 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,675 - [NOTICE] simulation.solve(784): Cycle 43/100 (4.297 s elapsed) --------------------
# 2021-09-24 15:15:56,675 - [NOTICE] simulation.solve(818): Cycle 43/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,694 - [NOTICE] simulation.solve(818): Cycle 43/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,717 - [NOTICE] simulation.solve(818): Cycle 43/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,738 - [NOTICE] simulation.solve(818): Cycle 43/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,765 - [NOTICE] simulation.solve(896): Capacity is now 4.058 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,766 - [NOTICE] simulation.solve(784): Cycle 44/100 (4.388 s elapsed) --------------------
# 2021-09-24 15:15:56,766 - [NOTICE] simulation.solve(818): Cycle 44/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,785 - [NOTICE] simulation.solve(818): Cycle 44/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,808 - [NOTICE] simulation.solve(818): Cycle 44/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,831 - [NOTICE] simulation.solve(818): Cycle 44/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,859 - [NOTICE] simulation.solve(896): Capacity is now 4.042 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,860 - [NOTICE] simulation.solve(784): Cycle 45/100 (4.482 s elapsed) --------------------
# 2021-09-24 15:15:56,860 - [NOTICE] simulation.solve(818): Cycle 45/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,878 - [NOTICE] simulation.solve(818): Cycle 45/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,901 - [NOTICE] simulation.solve(818): Cycle 45/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:56,922 - [NOTICE] simulation.solve(818): Cycle 45/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:56,950 - [NOTICE] simulation.solve(896): Capacity is now 4.026 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:56,951 - [NOTICE] simulation.solve(784): Cycle 46/100 (4.573 s elapsed) --------------------
# 2021-09-24 15:15:56,951 - [NOTICE] simulation.solve(818): Cycle 46/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:56,970 - [NOTICE] simulation.solve(818): Cycle 46/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:56,993 - [NOTICE] simulation.solve(818): Cycle 46/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:57,014 - [NOTICE] simulation.solve(818): Cycle 46/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:57,042 - [NOTICE] simulation.solve(896): Capacity is now 4.009 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:57,043 - [NOTICE] simulation.solve(784): Cycle 47/100 (4.665 s elapsed) --------------------
# 2021-09-24 15:15:57,043 - [NOTICE] simulation.solve(818): Cycle 47/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:57,062 - [NOTICE] simulation.solve(818): Cycle 47/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:57,085 - [NOTICE] simulation.solve(818): Cycle 47/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:57,106 - [NOTICE] simulation.solve(818): Cycle 47/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:57,134 - [NOTICE] simulation.solve(896): Capacity is now 3.994 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:57,134 - [NOTICE] simulation.solve(784): Cycle 48/100 (4.757 s elapsed) --------------------
# 2021-09-24 15:15:57,135 - [NOTICE] simulation.solve(818): Cycle 48/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:57,154 - [NOTICE] simulation.solve(818): Cycle 48/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:57,180 - [NOTICE] simulation.solve(818): Cycle 48/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:57,200 - [NOTICE] simulation.solve(818): Cycle 48/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:57,228 - [NOTICE] simulation.solve(896): Capacity is now 3.978 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:57,228 - [NOTICE] simulation.solve(784): Cycle 49/100 (4.850 s elapsed) --------------------
# 2021-09-24 15:15:57,228 - [NOTICE] simulation.solve(818): Cycle 49/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:57,247 - [NOTICE] simulation.solve(818): Cycle 49/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:57,271 - [NOTICE] simulation.solve(818): Cycle 49/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:57,291 - [NOTICE] simulation.solve(818): Cycle 49/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:57,320 - [NOTICE] simulation.solve(896): Capacity is now 3.962 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:57,320 - [NOTICE] simulation.solve(784): Cycle 50/100 (4.942 s elapsed) --------------------
# 2021-09-24 15:15:57,320 - [NOTICE] simulation.solve(818): Cycle 50/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:57,340 - [NOTICE] simulation.solve(818): Cycle 50/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:57,364 - [NOTICE] simulation.solve(818): Cycle 50/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:57,384 - [NOTICE] simulation.solve(818): Cycle 50/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:57,413 - [NOTICE] simulation.solve(902): Stopping experiment since capacity (3.947 Ah) is below stopping capacity (3.952 Ah).
# 2021-09-24 15:15:57,414 - [NOTICE] simulation.solve(913): Finish experiment simulation, took 5.036 s
# 2021-09-24 15:15:59,148 - [NOTICE] simulation.solve(784): Cycle 1/100 (25.119 ms elapsed) --------------------
# 2021-09-24 15:15:59,148 - [NOTICE] simulation.solve(818): Cycle 1/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:59,195 - [NOTICE] simulation.solve(818): Cycle 1/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:59,253 - [NOTICE] simulation.solve(818): Cycle 1/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:59,300 - [NOTICE] simulation.solve(818): Cycle 1/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:59,459 - [NOTICE] simulation.solve(896): Capacity is now 4.941 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:59,459 - [NOTICE] simulation.solve(784): Cycle 2/100 (336.543 ms elapsed) --------------------
# 2021-09-24 15:15:59,460 - [NOTICE] simulation.solve(818): Cycle 2/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:59,485 - [NOTICE] simulation.solve(818): Cycle 2/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:59,507 - [NOTICE] simulation.solve(818): Cycle 2/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:59,532 - [NOTICE] simulation.solve(818): Cycle 2/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:59,561 - [NOTICE] simulation.solve(896): Capacity is now 4.913 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:59,562 - [NOTICE] simulation.solve(784): Cycle 3/100 (438.948 ms elapsed) --------------------
# 2021-09-24 15:15:59,562 - [NOTICE] simulation.solve(818): Cycle 3/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:59,586 - [NOTICE] simulation.solve(818): Cycle 3/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:59,608 - [NOTICE] simulation.solve(818): Cycle 3/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:59,634 - [NOTICE] simulation.solve(818): Cycle 3/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:59,663 - [NOTICE] simulation.solve(896): Capacity is now 4.885 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:59,664 - [NOTICE] simulation.solve(784): Cycle 4/100 (540.786 ms elapsed) --------------------
# 2021-09-24 15:15:59,664 - [NOTICE] simulation.solve(818): Cycle 4/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:59,688 - [NOTICE] simulation.solve(818): Cycle 4/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:59,711 - [NOTICE] simulation.solve(818): Cycle 4/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:59,736 - [NOTICE] simulation.solve(818): Cycle 4/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:59,765 - [NOTICE] simulation.solve(896): Capacity is now 4.859 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:59,766 - [NOTICE] simulation.solve(784): Cycle 5/100 (643.082 ms elapsed) --------------------
# 2021-09-24 15:15:59,766 - [NOTICE] simulation.solve(818): Cycle 5/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:59,792 - [NOTICE] simulation.solve(818): Cycle 5/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:59,812 - [NOTICE] simulation.solve(818): Cycle 5/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:59,837 - [NOTICE] simulation.solve(818): Cycle 5/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:59,866 - [NOTICE] simulation.solve(896): Capacity is now 4.832 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:59,867 - [NOTICE] simulation.solve(784): Cycle 6/100 (744.008 ms elapsed) --------------------
# 2021-09-24 15:15:59,867 - [NOTICE] simulation.solve(818): Cycle 6/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:59,890 - [NOTICE] simulation.solve(818): Cycle 6/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:15:59,914 - [NOTICE] simulation.solve(818): Cycle 6/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:15:59,938 - [NOTICE] simulation.solve(818): Cycle 6/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:15:59,967 - [NOTICE] simulation.solve(896): Capacity is now 4.807 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:15:59,968 - [NOTICE] simulation.solve(784): Cycle 7/100 (845.043 ms elapsed) --------------------
# 2021-09-24 15:15:59,968 - [NOTICE] simulation.solve(818): Cycle 7/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:15:59,992 - [NOTICE] simulation.solve(818): Cycle 7/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,015 - [NOTICE] simulation.solve(818): Cycle 7/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,039 - [NOTICE] simulation.solve(818): Cycle 7/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,069 - [NOTICE] simulation.solve(896): Capacity is now 4.781 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,070 - [NOTICE] simulation.solve(784): Cycle 8/100 (946.794 ms elapsed) --------------------
# 2021-09-24 15:16:00,070 - [NOTICE] simulation.solve(818): Cycle 8/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,093 - [NOTICE] simulation.solve(818): Cycle 8/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,117 - [NOTICE] simulation.solve(818): Cycle 8/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,142 - [NOTICE] simulation.solve(818): Cycle 8/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,173 - [NOTICE] simulation.solve(896): Capacity is now 4.756 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,173 - [NOTICE] simulation.solve(784): Cycle 9/100 (1.051 s elapsed) --------------------
# 2021-09-24 15:16:00,174 - [NOTICE] simulation.solve(818): Cycle 9/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,197 - [NOTICE] simulation.solve(818): Cycle 9/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,220 - [NOTICE] simulation.solve(818): Cycle 9/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,245 - [NOTICE] simulation.solve(818): Cycle 9/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,275 - [NOTICE] simulation.solve(896): Capacity is now 4.731 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,275 - [NOTICE] simulation.solve(784): Cycle 10/100 (1.153 s elapsed) --------------------
# 2021-09-24 15:16:00,276 - [NOTICE] simulation.solve(818): Cycle 10/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,299 - [NOTICE] simulation.solve(818): Cycle 10/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,323 - [NOTICE] simulation.solve(818): Cycle 10/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,347 - [NOTICE] simulation.solve(818): Cycle 10/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,377 - [NOTICE] simulation.solve(896): Capacity is now 4.707 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,377 - [NOTICE] simulation.solve(784): Cycle 11/100 (1.254 s elapsed) --------------------
# 2021-09-24 15:16:00,378 - [NOTICE] simulation.solve(818): Cycle 11/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,400 - [NOTICE] simulation.solve(818): Cycle 11/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,424 - [NOTICE] simulation.solve(818): Cycle 11/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,449 - [NOTICE] simulation.solve(818): Cycle 11/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,479 - [NOTICE] simulation.solve(896): Capacity is now 4.683 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,479 - [NOTICE] simulation.solve(784): Cycle 12/100 (1.356 s elapsed) --------------------
# 2021-09-24 15:16:00,479 - [NOTICE] simulation.solve(818): Cycle 12/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,502 - [NOTICE] simulation.solve(818): Cycle 12/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,526 - [NOTICE] simulation.solve(818): Cycle 12/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,549 - [NOTICE] simulation.solve(818): Cycle 12/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,581 - [NOTICE] simulation.solve(896): Capacity is now 4.660 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,582 - [NOTICE] simulation.solve(784): Cycle 13/100 (1.459 s elapsed) --------------------
# 2021-09-24 15:16:00,582 - [NOTICE] simulation.solve(818): Cycle 13/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,605 - [NOTICE] simulation.solve(818): Cycle 13/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,630 - [NOTICE] simulation.solve(818): Cycle 13/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,654 - [NOTICE] simulation.solve(818): Cycle 13/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,684 - [NOTICE] simulation.solve(896): Capacity is now 4.637 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,684 - [NOTICE] simulation.solve(784): Cycle 14/100 (1.561 s elapsed) --------------------
# 2021-09-24 15:16:00,684 - [NOTICE] simulation.solve(818): Cycle 14/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,707 - [NOTICE] simulation.solve(818): Cycle 14/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,731 - [NOTICE] simulation.solve(818): Cycle 14/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,755 - [NOTICE] simulation.solve(818): Cycle 14/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,785 - [NOTICE] simulation.solve(896): Capacity is now 4.614 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,785 - [NOTICE] simulation.solve(784): Cycle 15/100 (1.662 s elapsed) --------------------
# 2021-09-24 15:16:00,785 - [NOTICE] simulation.solve(818): Cycle 15/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,808 - [NOTICE] simulation.solve(818): Cycle 15/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,831 - [NOTICE] simulation.solve(818): Cycle 15/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,856 - [NOTICE] simulation.solve(818): Cycle 15/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,885 - [NOTICE] simulation.solve(896): Capacity is now 4.591 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,886 - [NOTICE] simulation.solve(784): Cycle 16/100 (1.763 s elapsed) --------------------
# 2021-09-24 15:16:00,887 - [NOTICE] simulation.solve(818): Cycle 16/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:00,909 - [NOTICE] simulation.solve(818): Cycle 16/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:00,934 - [NOTICE] simulation.solve(818): Cycle 16/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:00,957 - [NOTICE] simulation.solve(818): Cycle 16/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:00,989 - [NOTICE] simulation.solve(896): Capacity is now 4.569 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:00,989 - [NOTICE] simulation.solve(784): Cycle 17/100 (1.867 s elapsed) --------------------
# 2021-09-24 15:16:00,990 - [NOTICE] simulation.solve(818): Cycle 17/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:01,013 - [NOTICE] simulation.solve(818): Cycle 17/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:01,036 - [NOTICE] simulation.solve(818): Cycle 17/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:01,061 - [NOTICE] simulation.solve(818): Cycle 17/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:01,090 - [NOTICE] simulation.solve(896): Capacity is now 4.547 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:01,091 - [NOTICE] simulation.solve(784): Cycle 18/100 (1.968 s elapsed) --------------------
# 2021-09-24 15:16:01,091 - [NOTICE] simulation.solve(818): Cycle 18/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:01,114 - [NOTICE] simulation.solve(818): Cycle 18/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:01,139 - [NOTICE] simulation.solve(818): Cycle 18/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:01,163 - [NOTICE] simulation.solve(818): Cycle 18/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:01,195 - [NOTICE] simulation.solve(896): Capacity is now 4.526 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:01,196 - [NOTICE] simulation.solve(784): Cycle 19/100 (2.074 s elapsed) --------------------
# 2021-09-24 15:16:01,197 - [NOTICE] simulation.solve(818): Cycle 19/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:01,221 - [NOTICE] simulation.solve(818): Cycle 19/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:01,246 - [NOTICE] simulation.solve(818): Cycle 19/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:01,271 - [NOTICE] simulation.solve(818): Cycle 19/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:01,305 - [NOTICE] simulation.solve(896): Capacity is now 4.504 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:01,306 - [NOTICE] simulation.solve(784): Cycle 20/100 (2.183 s elapsed) --------------------
# 2021-09-24 15:16:01,307 - [NOTICE] simulation.solve(818): Cycle 20/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:01,331 - [NOTICE] simulation.solve(818): Cycle 20/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:01,355 - [NOTICE] simulation.solve(818): Cycle 20/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:01,379 - [NOTICE] simulation.solve(818): Cycle 20/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:01,413 - [NOTICE] simulation.solve(896): Capacity is now 4.483 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:01,413 - [NOTICE] simulation.solve(784): Cycle 21/100 (2.290 s elapsed) --------------------
# 2021-09-24 15:16:01,414 - [NOTICE] simulation.solve(818): Cycle 21/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:01,436 - [NOTICE] simulation.solve(818): Cycle 21/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:01,460 - [NOTICE] simulation.solve(818): Cycle 21/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:01,494 - [NOTICE] simulation.solve(818): Cycle 21/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:01,526 - [NOTICE] simulation.solve(896): Capacity is now 4.462 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:01,527 - [NOTICE] simulation.solve(784): Cycle 22/100 (2.404 s elapsed) --------------------
# 2021-09-24 15:16:01,527 - [NOTICE] simulation.solve(818): Cycle 22/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:01,549 - [NOTICE] simulation.solve(818): Cycle 22/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:01,574 - [NOTICE] simulation.solve(818): Cycle 22/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:01,598 - [NOTICE] simulation.solve(818): Cycle 22/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:01,629 - [NOTICE] simulation.solve(896): Capacity is now 4.442 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:01,630 - [NOTICE] simulation.solve(784): Cycle 23/100 (2.507 s elapsed) --------------------
# 2021-09-24 15:16:01,630 - [NOTICE] simulation.solve(818): Cycle 23/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:01,652 - [NOTICE] simulation.solve(818): Cycle 23/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:01,676 - [NOTICE] simulation.solve(818): Cycle 23/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:01,700 - [NOTICE] simulation.solve(818): Cycle 23/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:01,730 - [NOTICE] simulation.solve(896): Capacity is now 4.421 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:01,731 - [NOTICE] simulation.solve(784): Cycle 24/100 (2.608 s elapsed) --------------------
# ...
# 2021-09-24 15:16:02,041 - [NOTICE] simulation.solve(896): Capacity is now 4.362 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,043 - [NOTICE] simulation.solve(784): Cycle 27/100 (2.920 s elapsed) --------------------
# 2021-09-24 15:16:02,043 - [NOTICE] simulation.solve(818): Cycle 27/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,065 - [NOTICE] simulation.solve(818): Cycle 27/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,088 - [NOTICE] simulation.solve(818): Cycle 27/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,115 - [NOTICE] simulation.solve(818): Cycle 27/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,144 - [NOTICE] simulation.solve(896): Capacity is now 4.343 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,145 - [NOTICE] simulation.solve(784): Cycle 28/100 (3.022 s elapsed) --------------------
# 2021-09-24 15:16:02,145 - [NOTICE] simulation.solve(818): Cycle 28/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,166 - [NOTICE] simulation.solve(818): Cycle 28/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,190 - [NOTICE] simulation.solve(818): Cycle 28/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,218 - [NOTICE] simulation.solve(818): Cycle 28/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,247 - [NOTICE] simulation.solve(896): Capacity is now 4.323 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,248 - [NOTICE] simulation.solve(784): Cycle 29/100 (3.125 s elapsed) --------------------
# 2021-09-24 15:16:02,248 - [NOTICE] simulation.solve(818): Cycle 29/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,269 - [NOTICE] simulation.solve(818): Cycle 29/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,295 - [NOTICE] simulation.solve(818): Cycle 29/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,317 - [NOTICE] simulation.solve(818): Cycle 29/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,348 - [NOTICE] simulation.solve(896): Capacity is now 4.304 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,348 - [NOTICE] simulation.solve(784): Cycle 30/100 (3.225 s elapsed) --------------------
# 2021-09-24 15:16:02,349 - [NOTICE] simulation.solve(818): Cycle 30/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,370 - [NOTICE] simulation.solve(818): Cycle 30/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,394 - [NOTICE] simulation.solve(818): Cycle 30/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,417 - [NOTICE] simulation.solve(818): Cycle 30/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,446 - [NOTICE] simulation.solve(896): Capacity is now 4.286 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,447 - [NOTICE] simulation.solve(784): Cycle 31/100 (3.324 s elapsed) --------------------
# 2021-09-24 15:16:02,447 - [NOTICE] simulation.solve(818): Cycle 31/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,468 - [NOTICE] simulation.solve(818): Cycle 31/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,492 - [NOTICE] simulation.solve(818): Cycle 31/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,515 - [NOTICE] simulation.solve(818): Cycle 31/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,544 - [NOTICE] simulation.solve(896): Capacity is now 4.267 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,545 - [NOTICE] simulation.solve(784): Cycle 32/100 (3.422 s elapsed) --------------------
# 2021-09-24 15:16:02,545 - [NOTICE] simulation.solve(818): Cycle 32/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,566 - [NOTICE] simulation.solve(818): Cycle 32/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,592 - [NOTICE] simulation.solve(818): Cycle 32/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,614 - [NOTICE] simulation.solve(818): Cycle 32/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,643 - [NOTICE] simulation.solve(896): Capacity is now 4.249 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,644 - [NOTICE] simulation.solve(784): Cycle 33/100 (3.521 s elapsed) --------------------
# 2021-09-24 15:16:02,644 - [NOTICE] simulation.solve(818): Cycle 33/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,665 - [NOTICE] simulation.solve(818): Cycle 33/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,689 - [NOTICE] simulation.solve(818): Cycle 33/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,711 - [NOTICE] simulation.solve(818): Cycle 33/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,740 - [NOTICE] simulation.solve(896): Capacity is now 4.231 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,741 - [NOTICE] simulation.solve(784): Cycle 34/100 (3.618 s elapsed) --------------------
# 2021-09-24 15:16:02,741 - [NOTICE] simulation.solve(818): Cycle 34/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,762 - [NOTICE] simulation.solve(818): Cycle 34/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,786 - [NOTICE] simulation.solve(818): Cycle 34/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,808 - [NOTICE] simulation.solve(818): Cycle 34/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,837 - [NOTICE] simulation.solve(896): Capacity is now 4.213 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,838 - [NOTICE] simulation.solve(784): Cycle 35/100 (3.715 s elapsed) --------------------
# 2021-09-24 15:16:02,838 - [NOTICE] simulation.solve(818): Cycle 35/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,859 - [NOTICE] simulation.solve(818): Cycle 35/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,883 - [NOTICE] simulation.solve(818): Cycle 35/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:02,906 - [NOTICE] simulation.solve(818): Cycle 35/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:02,935 - [NOTICE] simulation.solve(896): Capacity is now 4.195 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:02,936 - [NOTICE] simulation.solve(784): Cycle 36/100 (3.813 s elapsed) --------------------
# 2021-09-24 15:16:02,936 - [NOTICE] simulation.solve(818): Cycle 36/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:02,956 - [NOTICE] simulation.solve(818): Cycle 36/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:02,982 - [NOTICE] simulation.solve(818): Cycle 36/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,005 - [NOTICE] simulation.solve(818): Cycle 36/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,034 - [NOTICE] simulation.solve(896): Capacity is now 4.177 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,035 - [NOTICE] simulation.solve(784): Cycle 37/100 (3.912 s elapsed) --------------------
# 2021-09-24 15:16:03,035 - [NOTICE] simulation.solve(818): Cycle 37/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,056 - [NOTICE] simulation.solve(818): Cycle 37/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,080 - [NOTICE] simulation.solve(818): Cycle 37/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,102 - [NOTICE] simulation.solve(818): Cycle 37/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,131 - [NOTICE] simulation.solve(896): Capacity is now 4.160 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,131 - [NOTICE] simulation.solve(784): Cycle 38/100 (4.008 s elapsed) --------------------
# 2021-09-24 15:16:03,131 - [NOTICE] simulation.solve(818): Cycle 38/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,152 - [NOTICE] simulation.solve(818): Cycle 38/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,175 - [NOTICE] simulation.solve(818): Cycle 38/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,197 - [NOTICE] simulation.solve(818): Cycle 38/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,226 - [NOTICE] simulation.solve(896): Capacity is now 4.142 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,227 - [NOTICE] simulation.solve(784): Cycle 39/100 (4.104 s elapsed) --------------------
# 2021-09-24 15:16:03,227 - [NOTICE] simulation.solve(818): Cycle 39/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,248 - [NOTICE] simulation.solve(818): Cycle 39/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,271 - [NOTICE] simulation.solve(818): Cycle 39/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,294 - [NOTICE] simulation.solve(818): Cycle 39/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,323 - [NOTICE] simulation.solve(896): Capacity is now 4.125 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,324 - [NOTICE] simulation.solve(784): Cycle 40/100 (4.201 s elapsed) --------------------
# 2021-09-24 15:16:03,324 - [NOTICE] simulation.solve(818): Cycle 40/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,344 - [NOTICE] simulation.solve(818): Cycle 40/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,370 - [NOTICE] simulation.solve(818): Cycle 40/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,392 - [NOTICE] simulation.solve(818): Cycle 40/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,421 - [NOTICE] simulation.solve(896): Capacity is now 4.108 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,422 - [NOTICE] simulation.solve(784): Cycle 41/100 (4.299 s elapsed) --------------------
# 2021-09-24 15:16:03,422 - [NOTICE] simulation.solve(818): Cycle 41/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,442 - [NOTICE] simulation.solve(818): Cycle 41/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,466 - [NOTICE] simulation.solve(818): Cycle 41/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,488 - [NOTICE] simulation.solve(818): Cycle 41/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,518 - [NOTICE] simulation.solve(896): Capacity is now 4.091 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,518 - [NOTICE] simulation.solve(784): Cycle 42/100 (4.395 s elapsed) --------------------
# 2021-09-24 15:16:03,518 - [NOTICE] simulation.solve(818): Cycle 42/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,538 - [NOTICE] simulation.solve(818): Cycle 42/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,562 - [NOTICE] simulation.solve(818): Cycle 42/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,584 - [NOTICE] simulation.solve(818): Cycle 42/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,613 - [NOTICE] simulation.solve(896): Capacity is now 4.075 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,614 - [NOTICE] simulation.solve(784): Cycle 43/100 (4.491 s elapsed) --------------------
# 2021-09-24 15:16:03,614 - [NOTICE] simulation.solve(818): Cycle 43/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,634 - [NOTICE] simulation.solve(818): Cycle 43/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,658 - [NOTICE] simulation.solve(818): Cycle 43/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,679 - [NOTICE] simulation.solve(818): Cycle 43/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,709 - [NOTICE] simulation.solve(896): Capacity is now 4.058 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,709 - [NOTICE] simulation.solve(784): Cycle 44/100 (4.586 s elapsed) --------------------
# 2021-09-24 15:16:03,710 - [NOTICE] simulation.solve(818): Cycle 44/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,730 - [NOTICE] simulation.solve(818): Cycle 44/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,756 - [NOTICE] simulation.solve(818): Cycle 44/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,778 - [NOTICE] simulation.solve(818): Cycle 44/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,807 - [NOTICE] simulation.solve(896): Capacity is now 4.042 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,807 - [NOTICE] simulation.solve(784): Cycle 45/100 (4.684 s elapsed) --------------------
# 2021-09-24 15:16:03,807 - [NOTICE] simulation.solve(818): Cycle 45/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,827 - [NOTICE] simulation.solve(818): Cycle 45/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,850 - [NOTICE] simulation.solve(818): Cycle 45/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,873 - [NOTICE] simulation.solve(818): Cycle 45/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,902 - [NOTICE] simulation.solve(896): Capacity is now 4.026 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,902 - [NOTICE] simulation.solve(784): Cycle 46/100 (4.779 s elapsed) --------------------
# 2021-09-24 15:16:03,903 - [NOTICE] simulation.solve(818): Cycle 46/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:03,922 - [NOTICE] simulation.solve(818): Cycle 46/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:03,946 - [NOTICE] simulation.solve(818): Cycle 46/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:03,969 - [NOTICE] simulation.solve(818): Cycle 46/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:03,998 - [NOTICE] simulation.solve(896): Capacity is now 4.009 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:03,998 - [NOTICE] simulation.solve(784): Cycle 47/100 (4.875 s elapsed) --------------------
# 2021-09-24 15:16:03,999 - [NOTICE] simulation.solve(818): Cycle 47/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:04,019 - [NOTICE] simulation.solve(818): Cycle 47/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:04,044 - [NOTICE] simulation.solve(818): Cycle 47/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:04,065 - [NOTICE] simulation.solve(818): Cycle 47/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:04,096 - [NOTICE] simulation.solve(896): Capacity is now 3.994 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:04,096 - [NOTICE] simulation.solve(784): Cycle 48/100 (4.973 s elapsed) --------------------
# 2021-09-24 15:16:04,097 - [NOTICE] simulation.solve(818): Cycle 48/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:04,116 - [NOTICE] simulation.solve(818): Cycle 48/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:04,141 - [NOTICE] simulation.solve(818): Cycle 48/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:04,162 - [NOTICE] simulation.solve(818): Cycle 48/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:04,191 - [NOTICE] simulation.solve(896): Capacity is now 3.978 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:04,191 - [NOTICE] simulation.solve(784): Cycle 49/100 (5.069 s elapsed) --------------------
# 2021-09-24 15:16:04,192 - [NOTICE] simulation.solve(818): Cycle 49/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:04,212 - [NOTICE] simulation.solve(818): Cycle 49/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:04,236 - [NOTICE] simulation.solve(818): Cycle 49/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:04,258 - [NOTICE] simulation.solve(818): Cycle 49/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:04,287 - [NOTICE] simulation.solve(896): Capacity is now 3.962 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:04,288 - [NOTICE] simulation.solve(784): Cycle 50/100 (5.165 s elapsed) --------------------
# 2021-09-24 15:16:04,288 - [NOTICE] simulation.solve(818): Cycle 50/100, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:04,308 - [NOTICE] simulation.solve(818): Cycle 50/100, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:04,333 - [NOTICE] simulation.solve(818): Cycle 50/100, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:04,354 - [NOTICE] simulation.solve(818): Cycle 50/100, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:04,383 - [NOTICE] simulation.solve(902): Stopping experiment since capacity (3.947 Ah) is below stopping capacity (3.952 Ah).
# 2021-09-24 15:16:04,384 - [NOTICE] simulation.solve(913): Finish experiment simulation, took 5.261 s

# %%
sol_int.cycles
# Out:
# [<pybamm.solvers.solution.Solution at 0x14ddd93a0>,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x14dd85f10>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x14d3411f0>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x1524cd220>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x151faeb20>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x152d6a640>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x152d62400>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x15203d670>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x152f88040>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x152f7f670>,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x152fb6820>]

# %%
sol_list.cycles
# Out:
# [<pybamm.solvers.solution.Solution at 0x14e05fca0>,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x153117a90>,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x153117070>,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  <pybamm.solvers.solution.Solution at 0x151cfaa90>,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# For the cycles that are saved, you can plot as usual (note off-by-1 indexing)

# %%
sol_list.cycles[44].plot(["Current [A]","Terminal voltage [V]"])
# Out:
# interactive(children=(FloatSlider(value=130.23147890700034, description='t', max=133.03234291931693, min=130.2…

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))
for cycle in sol_int.cycles:
    if cycle is not None:
        t = cycle["Time [h]"].data - cycle["Time [h]"].data[0]
        ax[0].plot(t, cycle["Current [A]"].data)
        ax[0].set_xlabel("Time [h]")
        ax[0].set_title("Current [A]")
        ax[1].plot(t, cycle["Terminal voltage [V]"].data)
        ax[1].set_xlabel("Time [h]")
        ax[1].set_title("Terminal voltage [V]")

# %% [markdown]
# All summary variables are always available for every cycle, since these are much less memory-intensive

# %%
fig, axes = plt.subplots(n,m,figsize=(10,6))
for var, ax in zip(vars_to_plot,axes.flat):
    ax.plot(sol_list.summary_variables["Cycle number"], sol_list.summary_variables[var])
    ax.set_xlabel("Cycle number")
    ax.set_ylabel(var)
    ax.set_xlim([1,sol_list.summary_variables["Cycle number"][-1]])
fig.tight_layout()

# %% [markdown]
# ## Starting solution

# %% [markdown]
# A simulation can be performed iteratively by using the `starting_solution` feature. For example, we first solve for 10 cycles

# %%
experiment = pybamm.Experiment([
    ("Charge at 1C until 4.2V", 
     "Hold at 4.2V until C/50",
     "Discharge at 1C until 3V",
     "Rest for 1 hour")
] * 10,
termination="80% capacity"
)
sim = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values)
sol = sim.solve()
# Out:
# 2021-09-24 15:16:06,706 - [NOTICE] simulation.solve(784): Cycle 1/10 (24.556 ms elapsed) --------------------
# 2021-09-24 15:16:06,706 - [NOTICE] simulation.solve(818): Cycle 1/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:06,751 - [NOTICE] simulation.solve(818): Cycle 1/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:06,807 - [NOTICE] simulation.solve(818): Cycle 1/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:06,852 - [NOTICE] simulation.solve(818): Cycle 1/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,226 - [NOTICE] simulation.solve(896): Capacity is now 4.941 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,226 - [NOTICE] simulation.solve(784): Cycle 2/10 (545.186 ms elapsed) --------------------
# 2021-09-24 15:16:07,227 - [NOTICE] simulation.solve(818): Cycle 2/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,252 - [NOTICE] simulation.solve(818): Cycle 2/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,275 - [NOTICE] simulation.solve(818): Cycle 2/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:07,300 - [NOTICE] simulation.solve(818): Cycle 2/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,329 - [NOTICE] simulation.solve(896): Capacity is now 4.913 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,330 - [NOTICE] simulation.solve(784): Cycle 3/10 (648.903 ms elapsed) --------------------
# 2021-09-24 15:16:07,330 - [NOTICE] simulation.solve(818): Cycle 3/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,356 - [NOTICE] simulation.solve(818): Cycle 3/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,377 - [NOTICE] simulation.solve(818): Cycle 3/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:07,402 - [NOTICE] simulation.solve(818): Cycle 3/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,432 - [NOTICE] simulation.solve(896): Capacity is now 4.885 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,432 - [NOTICE] simulation.solve(784): Cycle 4/10 (751.144 ms elapsed) --------------------
# 2021-09-24 15:16:07,432 - [NOTICE] simulation.solve(818): Cycle 4/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,456 - [NOTICE] simulation.solve(818): Cycle 4/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,478 - [NOTICE] simulation.solve(818): Cycle 4/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:07,502 - [NOTICE] simulation.solve(818): Cycle 4/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,531 - [NOTICE] simulation.solve(896): Capacity is now 4.859 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,531 - [NOTICE] simulation.solve(784): Cycle 5/10 (850.246 ms elapsed) --------------------
# 2021-09-24 15:16:07,532 - [NOTICE] simulation.solve(818): Cycle 5/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,555 - [NOTICE] simulation.solve(818): Cycle 5/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,575 - [NOTICE] simulation.solve(818): Cycle 5/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:07,598 - [NOTICE] simulation.solve(818): Cycle 5/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,627 - [NOTICE] simulation.solve(896): Capacity is now 4.832 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,627 - [NOTICE] simulation.solve(784): Cycle 6/10 (946.274 ms elapsed) --------------------
# 2021-09-24 15:16:07,628 - [NOTICE] simulation.solve(818): Cycle 6/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,650 - [NOTICE] simulation.solve(818): Cycle 6/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,672 - [NOTICE] simulation.solve(818): Cycle 6/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:07,695 - [NOTICE] simulation.solve(818): Cycle 6/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,725 - [NOTICE] simulation.solve(896): Capacity is now 4.807 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,725 - [NOTICE] simulation.solve(784): Cycle 7/10 (1.044 s elapsed) --------------------
# 2021-09-24 15:16:07,725 - [NOTICE] simulation.solve(818): Cycle 7/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,748 - [NOTICE] simulation.solve(818): Cycle 7/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,772 - [NOTICE] simulation.solve(818): Cycle 7/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:07,797 - [NOTICE] simulation.solve(818): Cycle 7/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,829 - [NOTICE] simulation.solve(896): Capacity is now 4.781 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,829 - [NOTICE] simulation.solve(784): Cycle 8/10 (1.148 s elapsed) --------------------
# 2021-09-24 15:16:07,829 - [NOTICE] simulation.solve(818): Cycle 8/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,854 - [NOTICE] simulation.solve(818): Cycle 8/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,883 - [NOTICE] simulation.solve(818): Cycle 8/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:07,908 - [NOTICE] simulation.solve(818): Cycle 8/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:07,938 - [NOTICE] simulation.solve(896): Capacity is now 4.756 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:07,938 - [NOTICE] simulation.solve(784): Cycle 9/10 (1.257 s elapsed) --------------------
# 2021-09-24 15:16:07,939 - [NOTICE] simulation.solve(818): Cycle 9/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:07,961 - [NOTICE] simulation.solve(818): Cycle 9/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:07,984 - [NOTICE] simulation.solve(818): Cycle 9/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,007 - [NOTICE] simulation.solve(818): Cycle 9/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,037 - [NOTICE] simulation.solve(896): Capacity is now 4.731 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,037 - [NOTICE] simulation.solve(784): Cycle 10/10 (1.356 s elapsed) --------------------
# 2021-09-24 15:16:08,037 - [NOTICE] simulation.solve(818): Cycle 10/10, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,059 - [NOTICE] simulation.solve(818): Cycle 10/10, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,084 - [NOTICE] simulation.solve(818): Cycle 10/10, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,108 - [NOTICE] simulation.solve(818): Cycle 10/10, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,137 - [NOTICE] simulation.solve(896): Capacity is now 4.707 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,137 - [NOTICE] simulation.solve(913): Finish experiment simulation, took 1.456 s

# %% [markdown]
# If we give `sol` as the starting solution this will then solve for the next 10 cycles

# %%
sol2 = sim.solve(starting_solution=sol)
# Out:
# 2021-09-24 15:16:08,172 - [NOTICE] simulation.solve(784): Cycle 11/20 (26.129 ms elapsed) --------------------
# 2021-09-24 15:16:08,173 - [NOTICE] simulation.solve(818): Cycle 11/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,195 - [NOTICE] simulation.solve(818): Cycle 11/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,218 - [NOTICE] simulation.solve(818): Cycle 11/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,242 - [NOTICE] simulation.solve(818): Cycle 11/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,362 - [NOTICE] simulation.solve(896): Capacity is now 4.683 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,362 - [NOTICE] simulation.solve(784): Cycle 12/20 (216.000 ms elapsed) --------------------
# 2021-09-24 15:16:08,363 - [NOTICE] simulation.solve(818): Cycle 12/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,384 - [NOTICE] simulation.solve(818): Cycle 12/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,407 - [NOTICE] simulation.solve(818): Cycle 12/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,430 - [NOTICE] simulation.solve(818): Cycle 12/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,459 - [NOTICE] simulation.solve(896): Capacity is now 4.660 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,459 - [NOTICE] simulation.solve(784): Cycle 13/20 (312.646 ms elapsed) --------------------
# 2021-09-24 15:16:08,459 - [NOTICE] simulation.solve(818): Cycle 13/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,481 - [NOTICE] simulation.solve(818): Cycle 13/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,504 - [NOTICE] simulation.solve(818): Cycle 13/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,527 - [NOTICE] simulation.solve(818): Cycle 13/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,556 - [NOTICE] simulation.solve(896): Capacity is now 4.637 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,557 - [NOTICE] simulation.solve(784): Cycle 14/20 (410.336 ms elapsed) --------------------
# 2021-09-24 15:16:08,557 - [NOTICE] simulation.solve(818): Cycle 14/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,579 - [NOTICE] simulation.solve(818): Cycle 14/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,603 - [NOTICE] simulation.solve(818): Cycle 14/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,626 - [NOTICE] simulation.solve(818): Cycle 14/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,654 - [NOTICE] simulation.solve(896): Capacity is now 4.614 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,654 - [NOTICE] simulation.solve(784): Cycle 15/20 (508.033 ms elapsed) --------------------
# 2021-09-24 15:16:08,655 - [NOTICE] simulation.solve(818): Cycle 15/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,676 - [NOTICE] simulation.solve(818): Cycle 15/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,699 - [NOTICE] simulation.solve(818): Cycle 15/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,722 - [NOTICE] simulation.solve(818): Cycle 15/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,750 - [NOTICE] simulation.solve(896): Capacity is now 4.591 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,750 - [NOTICE] simulation.solve(784): Cycle 16/20 (604.087 ms elapsed) --------------------
# 2021-09-24 15:16:08,751 - [NOTICE] simulation.solve(818): Cycle 16/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,772 - [NOTICE] simulation.solve(818): Cycle 16/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,795 - [NOTICE] simulation.solve(818): Cycle 16/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,817 - [NOTICE] simulation.solve(818): Cycle 16/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,848 - [NOTICE] simulation.solve(896): Capacity is now 4.569 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,848 - [NOTICE] simulation.solve(784): Cycle 17/20 (701.984 ms elapsed) --------------------
# 2021-09-24 15:16:08,849 - [NOTICE] simulation.solve(818): Cycle 17/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,871 - [NOTICE] simulation.solve(818): Cycle 17/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,894 - [NOTICE] simulation.solve(818): Cycle 17/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:08,917 - [NOTICE] simulation.solve(818): Cycle 17/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:08,946 - [NOTICE] simulation.solve(896): Capacity is now 4.547 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:08,946 - [NOTICE] simulation.solve(784): Cycle 18/20 (799.749 ms elapsed) --------------------
# 2021-09-24 15:16:08,946 - [NOTICE] simulation.solve(818): Cycle 18/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:08,968 - [NOTICE] simulation.solve(818): Cycle 18/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:08,991 - [NOTICE] simulation.solve(818): Cycle 18/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:09,014 - [NOTICE] simulation.solve(818): Cycle 18/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:09,043 - [NOTICE] simulation.solve(896): Capacity is now 4.526 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:09,043 - [NOTICE] simulation.solve(784): Cycle 19/20 (897.125 ms elapsed) --------------------
# 2021-09-24 15:16:09,044 - [NOTICE] simulation.solve(818): Cycle 19/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:09,065 - [NOTICE] simulation.solve(818): Cycle 19/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:09,088 - [NOTICE] simulation.solve(818): Cycle 19/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:09,110 - [NOTICE] simulation.solve(818): Cycle 19/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:09,140 - [NOTICE] simulation.solve(896): Capacity is now 4.504 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:09,141 - [NOTICE] simulation.solve(784): Cycle 20/20 (994.539 ms elapsed) --------------------
# 2021-09-24 15:16:09,141 - [NOTICE] simulation.solve(818): Cycle 20/20, step 1/4: Charge at 1C until 4.2V
# 2021-09-24 15:16:09,162 - [NOTICE] simulation.solve(818): Cycle 20/20, step 2/4: Hold at 4.2V until C/50
# 2021-09-24 15:16:09,185 - [NOTICE] simulation.solve(818): Cycle 20/20, step 3/4: Discharge at 1C until 3V
# 2021-09-24 15:16:09,207 - [NOTICE] simulation.solve(818): Cycle 20/20, step 4/4: Rest for 1 hour
# 2021-09-24 15:16:09,236 - [NOTICE] simulation.solve(896): Capacity is now 4.483 Ah (originally 4.941 Ah, will stop at 3.952 Ah)
# 2021-09-24 15:16:09,237 - [NOTICE] simulation.solve(913): Finish experiment simulation, took 1.090 s

# %% [markdown]
# We have now simulated 20 cycles

# %%
len(sol2.cycles)
# Out:
# 20

# %%
sol2.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=61.077971817103816, step=0.6107797181710382)…
